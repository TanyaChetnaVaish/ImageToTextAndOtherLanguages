# %%
import cv2
import pytesseract
from pytesseract.pytesseract import Output
# %matplotlib inline
pytesseract.pytesseract.tesseract_cmd=r'E:/Tesseract-OCR/tesseract.exe'
import numpy as np
from matplotlib import pyplot as plt

# %%
#from PIL import Image
img = cv2.imread('E:/new123.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
pytesseract
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
def remove_noise(image):
    return cv2.medianBlur(image,5)
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# %%
rem_noise = remove_noise(img)
gray = get_grayscale(rem_noise)
thresh = thresholding(gray)
print(pytesseract.image_to_string(img))
# Out:
# IBM Career Education — Software Foundation
#
# Rational Software Architect is a robust, scalable platform for solution architecture
# factories for corporate IT, SOA, and general development. It supports Java, JEE, cx,
#
# Microsoft .NET, SCA, Web 2.0, and more.
#
#
#
# Rational Rhapsody is a visual development environment for systems Engineers ang Sot
# developers creating real-time or embedded systems and software. It also Provides a Visual
# representation of the Android framework API that developers can reference from Within Rat
# Rhapsody. The references are then generated into Java code to automate the Manual coding
# task. By using the full behavioral code generation capability of IBM Rational Rhapsody Deve,
# for Java, Android developers can quickly create the behavior of applications that Teferences
#
#
#
#
#
#
#
# Android and deploy to their Android targets.
#
# Worklight provides an open and advanced mobile application platform and tools Software for
# smartphones and tablets. Worklight products offer flexible mobile IDE, next-generation mobile
#
# middleware, end-to-end security and integrated management and analytics.
#
# INFO: Eclipse is the Android's official development Platform that allows rapid development using
# a plugin called Android Development Tools(ADT). This can help leverage Eclipse's rich featues

# %%
plt.imshow(img)
plt.show()

# %%
pytesseract.image_to_string(img)
# Out:
# "IBM Career Education — Software Foundation\n\nRational Software Architect is a robust, scalable platform for solution architecture\nfactories for corporate IT, SOA, and general development. It supports Java, JEE, cx,\n\nMicrosoft .NET, SCA, Web 2.0, and more.\n\n  \n\nRational Rhapsody is a visual development environment for systems Engineers ang Sot\ndevelopers creating real-time or embedded systems and software. It also Provides a Visual\nrepresentation of the Android framework API that developers can reference from Within Rat\nRhapsody. The references are then generated into Java code to automate the Manual coding\ntask. By using the full behavioral code generation capability of IBM Rational Rhapsody Deve,\nfor Java, Android developers can quickly create the behavior of applications that Teferences\n\n \n\n  \n\n \n\nAndroid and deploy to their Android targets.\n\nWorklight provides an open and advanced mobile application platform and tools Software for\nsmartphones and tablets. Worklight products offer flexible mobile IDE, next-generation mobile\n\nmiddleware, end-to-end security and integrated management and analytics.\n\nINFO: Eclipse is the Android's official development Platform that allows rapid development using\na plugin called Android Development Tools(ADT). This can help leverage Eclipse's rich featues\n\n \n\x0c"

# %%
# !pip install textblob
import numpy as np
import re
import nltk
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from textblob import TextBlob
# Out:
# Requirement already satisfied: textblob in e:\spyder\lib\site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in e:\spyder\lib\site-packages (from textblob) (3.4.5)
# Requirement already satisfied: six in e:\spyder\lib\site-packages (from nltk>=3.1->textblob) (1.14.0)

# %%
def text_processing(tweet):
    
    def form_sentence(tweet):
        tweet_blob = TextBlob(tweet)
        return ' '.join(tweet_blob.words)
    new_tweet = form_sentence(tweet)
    
    def no_user_alpha(tweet):
        tweet_list = [ele for ele in tweet.split() if ele != 'user']
        clean_tokens = [t for t in tweet_list if re.match(r'[^\W\d]*$', t)]
        clean_s = ' '.join(clean_tokens)
        clean_mess = [word for word in clean_s.split() if word.lower() not in set(stopwords.words('english'))]
        return clean_mess
    no_punc_tweet = no_user_alpha(new_tweet)
    
    def normalization(tweet_list):
        lem = WordNetLemmatizer()
        normalized_tweet = []
        for word in tweet_list:
            normalized_text = lem.lemmatize(word)
            normalized_tweet.append(normalized_text)
        return normalized_tweet
    return normalization(no_punc_tweet)

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
var=text_processing(pytesseract.image_to_string(img))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\TANYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\TANYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\TANYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
set(var)
# Out:
# {'ADT',
#  'API',
#  'Android',
#  'Architect',
#  'Career',
#  'Deve',
#  'Development',
#  'Eclipse',
#  'Education',
#  'Engineers',
#  'Foundation',
#  'IBM',
#  'IDE',
#  'INFO',
#  'JEE',
#  'Java',
#  'Manual',
#  'Microsoft',
#  'NET',
#  'Platform',
#  'Provides',
#  'Rat',
#  'Rational',
#  'Rhapsody',
#  'SCA',
#  'SOA',
#  'Software',
#  'Sot',
#  'Teferences',
#  'Tools',
#  'Visual',
#  'Web',
#  'Within',
#  'Worklight',
#  'advanced',
#  'allows',
#  'also',
#  'analytics',
#  'ang',
#  'application',
#  'architecture',
#  'automate',
#  'behavior',
#  'behavioral',
#  'called',
#  'capability',
#  'code',
#  'coding',
#  'corporate',
#  'create',
#  'creating',
#  'cx',
#  'deploy',
#  'developer',
#  'development',
#  'embedded',
#  'environment',
#  'factory',
#  'featues',
#  'flexible',
#  'framework',
#  'full',
#  'general',
#  'generated',
#  'generation',
#  'help',
#  'integrated',
#  'leverage',
#  'management',
#  'middleware',
#  'mobile',
#  'offer',
#  'official',
#  'open',
#  'platform',
#  'plugin',
#  'product',
#  'provides',
#  'quickly',
#  'rapid',
#  'reference',
#  'representation',
#  'rich',
#  'robust',
#  'scalable',
#  'security',
#  'smartphones',
#  'software',
#  'solution',
#  'support',
#  'system',
#  'tablet',
#  'target',
#  'task',
#  'tool',
#  'using',
#  'visual'}

# %%
from openpyxl import Workbook
workbook = Workbook()
sheet = workbook.active

# %%
sheet["A1"] = "WORDS"
sheet["B1"] = "SYNONYMS"
sheet["C1"] = "ANTONYMS"
sheet["D1"] = "HINDI"
sheet["E1"] = "PUNJABI"
sheet["F1"] = "TAMIL"
sheet["G1"] = "TELUGU"

workbook.save(filename="translate.xlsx")

# %%
lwords=[]
j=2
for i in range(len(var)):
    lwords.append(var[i])
    s="A"+str(j)
    sheet[s]=var[i]
    j=j+1
    workbook.save(filename="translate.xlsx")
j=2

# %%
synonyms = []
antonyms = []
js=2
for i in lwords:
    synonyms=[]
    for syn in wordnet.synsets(i):
        for lm in syn.lemmas():
             synonyms.append(lm.name())#adding into synonyms
    if len(synonyms)>0:
        s="B"+str(js)
        sheet[s]=synonyms[0]
        workbook.save(filename="translate.xlsx")
    js=js+1
js=2
for i in lwords:
    antonyms=[]
    for syn in wordnet.synsets(i):
        for lm in syn.lemmas():
            if lm.antonyms():
                antonyms.append(lm.antonyms()[0].name()) #adding into antonyms
    if len(antonyms)>0:
        s="C"+str(js)
        sheet[s]=antonyms[0]
        workbook.save(filename="translate.xlsx")
    js=js+1
js=2

# %%
from nltk.corpus import wordnet

# %%
from google_trans_new import google_translator  
ltranswordshindi=[]
ltranswordspunjabi=[]
ltranswordstamil=[]
ltranswordstelugu=[]
translator = google_translator()  
for i in var:
  translate_text = translator.translate(i,lang_tgt='hi')  
  ltranswordshindi.append(translate_text)
  translate_text = translator.translate(i,lang_tgt='ta')
  ltranswordstamil.append(translate_text)
  translate_text = translator.translate(i,lang_tgt='te')
  ltranswordstelugu.append(translate_text)
  translate_text = translator.translate(i,lang_tgt='pa')
  ltranswordspunjabi.append(translate_text)

# %%
j=2
for i in range(len(lwords)):
    shindi="D"+str(j)
    spu="E"+str(j)
    sta="F"+str(j)
    ste="G"+str(j)
    sheet[shindi]=ltranswordshindi[i]
    sheet[spu]=ltranswordspunjabi[i]
    sheet[sta]=ltranswordstamil[i]
    sheet[ste]=ltranswordstelugu[i]
    j=j+1
    workbook.save(filename="translate.xlsx")
j=2
